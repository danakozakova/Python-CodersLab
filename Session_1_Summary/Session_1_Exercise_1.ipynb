# %% [markdown]
# # Session 1 - Shrnutí
#
# ## Počítání znaků v řetězci pomocí slovníku

# %% [markdown]
# ## 🔧 CVIČENÍ 1 - Diskuse
#
# ### Zadání
#
# Napište funkci `count_letters(text)`, která přijímá řetězec jako argument a vrací slovník se znaky řetězce jako klíči a počtem výskytů jako hodnotami.
#
# **Příklad:**
#
# ```python
# print(count_letters('Katharina'))
# ```
#
# **Výsledek:**
#
# ```python
# {'K': 1, 'a': 3, 't': 1, 'h': 1, 'r': 1, 'i': 1, 'n': 1}
# ```

# %% [markdown]
# ### Diskuse
#
# Jak byste provedli takový úkol, kdyby řetězec byl řada magnetických písmen na lednici a k dispozici byl pouze tužka a poznámkový blok?
#
# Pravděpodobně byste nakreslili prázdnou tabulku se dvěma sloupci. Podívali byste se na první písmeno - je již zahrnuto v tabulce? Pokud ne, vytvoříte nový řádek a do druhého sloupce napíšete "1". Pokud takové písmeno již bylo, přečtete si jeho předchozí počet a nahradíte ho novým, zvýšeným o 1.
#
# Když jsou všechna písmena hotová, tabulka v poznámkovém bloku bude řešením úlohy. Teď uděláme totéž, ale v Pythonu.

# %% [markdown]
# ---
#
# ## Řešení krok za krokem

# %% [markdown]
# ### Krok 1: Deklarace funkce
#
# Začneme deklarací funkce `count_letters`:
#
# Klíčové slovo `pass` je zde jen proto, aby byla zajištěna správná syntaxe programu: funkce nemohou být prázdné.

# %% [markdown]
# ### Krok 2: Vytvoření slovníku pro ukládání počtů
#
# Dále vytvoříme slovník, který bude ukládat počty všech písmen:

# %% [markdown]
# ### Krok 3: Procházení každého písmene
#
# Dalším krokem bude navštívit každé písmeno v řetězci pomocí cyklu `for`:

# %% [markdown]
# ### Krok 4: Přidání nového písmene do slovníku
#
# V těle cyklu `for` máme možnost provést stejný kód mnohokrát, s jiným písmenem `letter` z řetězce `text` při každém provedení.
#
# Pokud takové písmeno ve slovníku ještě není, přidáme ho s počítadlem rovným `1` (protože jsme ho potkali poprvé):

# %% [markdown]
# ### Krok 5: Počítání opakovaných výskytů
#
# Již víme, že písmena ve slovníku byla alespoň jednou v `text`: nyní je čas počítat druhý a další výskyty:

# %% [markdown]
# ### Krok 6: Vrácení výsledku
#
# Funkce počítá písmena správně, ale nevrací výsledek. Musíme přidat klíčové slovo `return`, které určuje hodnotu, která bude výsledkem funkce:

# %% [markdown]
# ### Finální testování
#
# Nyní otestujeme hotovou funkci:

# %%
print(count_letters('Katharina'))
# Out:
# {'K': 1, 'a': 3, 't': 1, 'h': 1, 'r': 1, 'i': 1, 'n': 1}

# %%
print(count_letters('Python'))
# Out:
# {'P': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %%
print(count_letters('programování'))
# Out:
# {'p': 1, 'r': 2, 'o': 2, 'g': 1, 'a': 1, 'm': 1, 'v': 1, 'á': 1, 'n': 1, 'í': 1}

# %% [markdown]
# ---
#
# ## 💭 Otázky k zamyšlení
#
# 1. Co se stane, když zavoláme funkci s prázdným řetězcem? Vyzkoušejte: `count_letters('')`
#
# 2. Jak byste upravili funkci, aby nebrala v úvahu mezery?
#
# 3. Jak byste upravili funkci, aby nerozlišovala velká a malá písmena? (např. 'A' a 'a' by se počítaly společně)

# %%
# Váš kód zde:
