# %% [markdown]
# # Merge - spojování tabulek v Pandas
#
# V Pandas je ekvivalentem SQL příkazu `JOIN` funkce `merge`. Slouží ke spojení dvou nebo více tabulek do jedné na základě zadaných podmínek.
#
# Dostupné typy spojení:
# - `left` - použije všechny řádky z levé tabulky
# - `right` - použije všechny řádky z pravé tabulky
# - `inner` - použije pouze společné řádky (výchozí)
# - `outer` - použije všechny řádky z obou tabulek
# - `cross` - spojí každý řádek s každým (od Pandas 1.2.0)

# %% [markdown]
# ## 1. Import knihovny a příprava dat

# %%
import pandas as pd

# %%
# Vytvoříme DataFrame s názvy krajů (simulace dat ze souboru)
df_province = pd.DataFrame({
    'province': ['DOLNÍ SLEZSKO', 'LUBUŠSKO', 'ZÁPADNÍ POMOŘANSKO', 
                 'VELKOPOLSKO', 'MALOPOLSKO', 'MAZOVSKO']
})

# %%
df_province

# %%
# Vytvoříme "slovník" krajů (některé existující + jeden nový, který ještě není v datech)
d_province = pd.DataFrame(
    columns=['d_province'],
    data=['DOLNÍ SLEZSKO', 'LUBUŠSKO', 'ZÁPADNÍ POMOŘANSKO', 'VARŠAVSKÝ OBVOD']
)

# %%
d_province

# %% [markdown]
# ## 2. Funkce merge - základní parametry
#
# ```python
# pd.merge(
#     left,      # první DataFrame
#     right,     # druhý DataFrame
#     how,       # typ spojení: 'left', 'right', 'inner', 'outer', 'cross'
#     on,        # sloupec pro spojení (pokud má stejný název v obou tabulkách)
#     left_on,   # sloupec z levé tabulky
#     right_on   # sloupec z pravé tabulky
# )
# ```
#
# Parametry `left_on` a `right_on` používáme, když se názvy sloupců liší.

# %% [markdown]
# ## 3. LEFT JOIN
#
# Použije všechny řádky z levé tabulky. Pokud není shoda v pravé tabulce, hodnoty budou `NaN`.

# %%
# Spojení pomocí left join
left_join_example = pd.merge(
    left=df_province,
    right=d_province,
    how='left',
    left_on=['province'],
    right_on=['d_province']
)

# %%
left_join_example
# Out:
#              province          d_province
# 0       DOLNÍ SLEZSKO       DOLNÍ SLEZSKO
# 1            LUBUŠSKO            LUBUŠSKO
# 2  ZÁPADNÍ POMOŘANSKO  ZÁPADNÍ POMOŘANSKO
# 3         VELKOPOLSKO                 NaN
# 4          MALOPOLSKO                 NaN
# 5            MAZOVSKO                 NaN

# %% [markdown]
# **Otázka:** Proč mají některé řádky hodnotu `NaN` ve sloupci `d_province`?

# %% [markdown]
# ## 4. RIGHT JOIN
#
# Použije všechny řádky z pravé tabulky. Je to opak `left join` - můžeme je vzájemně zaměnit prohozením tabulek.

# %%
# Spojení pomocí right join
right_join_example = pd.merge(
    left=df_province,
    right=d_province,
    how='right',
    left_on=['province'],
    right_on=['d_province']
)

# %%
right_join_example
# Out:
#              province          d_province
# 0       DOLNÍ SLEZSKO       DOLNÍ SLEZSKO
# 1            LUBUŠSKO            LUBUŠSKO
# 2  ZÁPADNÍ POMOŘANSKO  ZÁPADNÍ POMOŘANSKO
# 3                 NaN     VARŠAVSKÝ OBVOD

# %% [markdown]
# **Otázka:** Který kraj se objevil, který nebyl v původních datech `df_province`?

# %% [markdown]
# ## 5. INNER JOIN
#
# Vrátí pouze řádky, které existují v obou tabulkách (průnik). Toto je **výchozí** typ spojení.

# %%
# Spojení pomocí inner join
inner_join_example = pd.merge(
    left=df_province,
    right=d_province,
    how='inner',  # můžeme vynechat, je to výchozí hodnota
    left_on=['province'],
    right_on=['d_province']
)

# %%
inner_join_example
# Out:
#              province          d_province
# 0       DOLNÍ SLEZSKO       DOLNÍ SLEZSKO
# 1            LUBUŠSKO            LUBUŠSKO
# 2  ZÁPADNÍ POMOŘANSKO  ZÁPADNÍ POMOŘANSKO

# %%
print(f"Počet řádků: {len(inner_join_example)}")
# Out:
# Počet řádků: 3

# %% [markdown]
# ## 6. OUTER JOIN
#
# Vrátí všechny řádky z obou tabulek (sjednocení). Chybějící hodnoty budou `NaN`.

# %%
# Spojení pomocí outer join
outer_join_example = pd.merge(
    left=df_province,
    right=d_province,
    how='outer',
    left_on=['province'],
    right_on=['d_province']
)

# %%
outer_join_example
# Out:
#              province          d_province
# 0       DOLNÍ SLEZSKO       DOLNÍ SLEZSKO
# 1            LUBUŠSKO            LUBUŠSKO
# 2          MALOPOLSKO                 NaN
# 3            MAZOVSKO                 NaN
# 4                 NaN     VARŠAVSKÝ OBVOD
# 5         VELKOPOLSKO                 NaN
# 6  ZÁPADNÍ POMOŘANSKO  ZÁPADNÍ POMOŘANSKO

# %%
print(f"Počet řádků: {len(outer_join_example)}")
# Out:
# Počet řádků: 7

# %% [markdown]
# **Otázka:** Proč má `outer join` více řádků než `inner join`?

# %% [markdown]
# ## 7. CROSS JOIN
#
# Spojí každý řádek z levé tabulky s každým řádkem z pravé tabulky. **Pozor:** Může vytvořit velmi velkou tabulku! (n × m řádků)

# %%
# Spojení pomocí cross join
cross_join_example = pd.merge(
    left=df_province,
    right=d_province,
    how='cross'
    # u cross join nezadáváme podmínku spojení
)

# %%
cross_join_example
# Out:
#               province          d_province
# 0        DOLNÍ SLEZSKO       DOLNÍ SLEZSKO
# 1        DOLNÍ SLEZSKO            LUBUŠSKO
# 2        DOLNÍ SLEZSKO  ZÁPADNÍ POMOŘANSKO
# 3        DOLNÍ SLEZSKO     VARŠAVSKÝ OBVOD
# 4             LUBUŠSKO       DOLNÍ SLEZSKO
# 5             LUBUŠSKO            LUBUŠSKO
# 6             LUBUŠSKO  ZÁPADNÍ POMOŘANSKO
# 7             LUBUŠSKO     VARŠAVSKÝ OBVOD
# 8   ZÁPADNÍ POMOŘANSKO       DOLNÍ SLEZSKO
# 9   ZÁPADNÍ POMOŘANSKO            LUBUŠSKO
# 10  ZÁPADNÍ POMOŘANSKO  ZÁPADNÍ POMOŘANSKO
# 11  ZÁPADNÍ POMOŘANSKO     VARŠAVSKÝ OBVOD
# 12         VELKOPOLSKO       DOLNÍ SLEZSKO
# 13         VELKOPOLSKO            LUBUŠSKO
# 14         VELKOPOLSKO  ZÁPADNÍ POMOŘANSKO
# 15         VELKOPOLSKO     VARŠAVSKÝ OBVOD
# 16          MALOPOLSKO       DOLNÍ SLEZSKO
# 17          MALOPOLSKO            LUBUŠSKO
# 18          MALOPOLSKO  ZÁPADNÍ POMOŘANSKO
# 19          MALOPOLSKO     VARŠAVSKÝ OBVOD
# 20            MAZOVSKO       DOLNÍ SLEZSKO
# 21            MAZOVSKO            LUBUŠSKO
# 22            MAZOVSKO  ZÁPADNÍ POMOŘANSKO
# 23            MAZOVSKO     VARŠAVSKÝ OBVOD

# %%
print(f"Počet řádků: {len(cross_join_example)}")
print(f"Očekáváno: {len(df_province)} × {len(d_province)} = {len(df_province) * len(d_province)}")
# Out:
# Počet řádků: 24
# Očekáváno: 6 × 4 = 24

# %% [markdown]
# ## 8. Merge s podmínkami
#
# V Pandas můžeme při `merge` použít pouze operátor `==`. Pro složitější podmínky (jako `>=`, `<` atd.) musíme:
# 1. Nejprve udělat `cross join`
# 2. Poté filtrovat pomocí `loc` nebo `query`

# %% [raw]
# Prve riesenie: s odlozenim medzivysledku "gp"

# %%
# Najdeme kraje, kde název v province je >= než název v d_province
gp = pd.merge(
    left=df_province,
    right=d_province,
    how='cross'
)

# %%
# maska df['province'] > df['d_province']

gp.loc[gp['province'] >= gp['d_province']]

# %%
# Filtrujeme výsledek
result = gp.loc[gp['province'] >= gp['d_province']].sort_values('province')

# %%
result

# %% [raw]
# Krajsie - riesenie na 1 zreťazený riadok s pomocou "query"

# %%
result = pd.merge(left = df_province,
                  right = d_province,
                  how = 'cross'
                 ).query("province >= d_province").sort_values('province')
result

# %% [raw]
# "Syntakticky zlozitejsie" - riesenie na 1 riadok s pomocou "loc"

# %%
result = pd.merge(left = df_province,
                  right = d_province,
                  how = 'cross'
                 ).loc[lambda x: x['province'] >= x['d_province']].sort_values('province')
result

# %% [markdown]
# ---
# ## Úlohy na opravu chyb
#
# V následujících buňkách jsou chyby. Opravte je.

# %% [markdown]
# ### Úloha 1: Opravte chybu v merge

# %%
# OPRAVTE: Chceme left join, ale kód nefunguje správně
result = pd.merge(
    left=df_province,
    right=d_province,
    how='left',
    on='province'  
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19100\3711976783.py in ?()
#       1 # OPRAVTE: Chceme left join, ale kód nefunguje správně
# ----> 2 result = pd.merge(
#       3     left=df_province,
#       4     right=d_province,
#       5     how='left',
#
# C:\ProgramData\miniconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# C:\ProgramData\miniconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# C:\ProgramData\miniconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1293                         # Then we're either Hashable or a wrong-length arraylike,
#    1294                         #  the latter of which will raise
#    1295                         rk = cast(Hashable, rk)
#    1296                         if rk is not None:
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#    1298                         else:
#    1299                             # work-around for merge_asof(right_index=True)
#    1300                             right_keys.append(right.index._values)
#
# C:\ProgramData\miniconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'province'

# %%
# OPRAVTE: Chceme left join, ale kód nefunguje správně
result = pd.merge(
    left=df_province,
    right=d_province,
    how='left',
    left_on='province',
    right_on='d_province' 
)

# %% [markdown]
# ### Úloha 2: Opravte syntaxi

# %%
# OPRAVTE: Cross join nefunguje
result = pd.merge(
    left=df_province,
    right=d_province,
    how='cross',
    left_on=['province'],  
    right_on=['d_province']
)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 # OPRAVTE: Cross join nefunguje
# ----> 2 result = pd.merge(
#       3     left=df_province,
#       4     right=d_province,
#       5     how='cross',
#       6     left_on=['province'],
#       7     right_on=['d_province']
#       8 )
#
# File C:\ProgramData\miniconda3\Lib\site-packages\pandas\core\reshape\merge.py:155, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     153 right_df = _validate_operand(right)
#     154 if how == "cross":
# --> 155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#     158         on=on,
#     159         left_on=left_on,
#     160         right_on=right_on,
#     161         left_index=left_index,
#     162         right_index=right_index,
#     163         sort=sort,
#     164         suffixes=suffixes,
#     165         indicator=indicator,
#     166         validate=validate,
#     167         copy=copy,
#     168     )
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
#
# File C:\ProgramData\miniconda3\Lib\site-packages\pandas\core\reshape\merge.py:212, in _cross_merge(left, right, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     201 """
#     202 See merge.__doc__ with how='cross'
#     203 """
#     205 if (
#     206     left_index
#     207     or right_index
#    (...)
#     210     or on is not None
#     211 ):
# --> 212     raise MergeError(
#     213         "Can not pass on, right_on, left_on or set right_index=True or "
#     214         "left_index=True"
#     215     )
#     217 cross_col = f"_cross_{uuid.uuid4()}"
#     218 left = left.assign(**{cross_col: 1})
#
# MergeError: Can not pass on, right_on, left_on or set right_index=True or left_index=True

# %%
# OPRAVTE: Cross join nefunguje
result = pd.merge(
    left=df_province,
    right=d_province,
    how='cross'
)

# %% [markdown]
# ---
# ## Cvičení

# %% [markdown]
# ### Cvičení 1: Normalizace datasetu
#
# V listech souboru **dims.xlsx** jsou slovníky pro data ze souboru **product_prices_cleaned.csv**. Pomocí `merge` normalizujte data podle následujících kroků:
#
# 1. Načtěte obsah listů souboru **dims.xlsx** do samostatných `DataFrame`. Pro přehlednost pojmenujte rámce podle názvů listů.
#
# 2. Načtěte data ze souboru **product_prices_cleaned.csv** do proměnné `df`.
#
# 3. Na základě listu **d_province** pomocí sloupce `id` přidejte do rámce `df` sloupec `province_id`.
#
# 4. Na základě listu **d_product** přidejte do rámce `df` sloupec `product_id`.
#
# 5. Z tabulky extrahujte pouze sloupce, které odkazují na jiné tabulky (např. **product_id**) a sloupce **value**, **date**. Myslíte, že je to přehlednější? Jaké jsou potenciální výhody tohoto přístupu?
#
# > Více o normalizaci databází najdete na [odkazu](https://www.sqlshack.com/what-is-database-normalization-in-sql-server/).

# %% [raw]
# 1. nacitanie ciselnikovych df

# %%
# Váš kód zde
f = pd.ExcelFile('../Data/dims.xlsx')
f.sheet_names
# Out:
# ['d_province', 'd_product', 'd_product_group']

# %%
d_province = pd.read_excel('../Data/dims.xlsx', sheet_name='d_province')
d_province.head(2)
# Out:
#    province_id      province
# 0            8  SUBCARPATHIA
# 1           14          ŁÓDŹ

# %%
d_product = pd.read_excel('../Data/dims.xlsx', sheet_name='d_product')
d_product.head(2)
# Out:
#    product_id                    product  product_group_id
# 0          20  pork ham cooked - per 1kg                 2
# 1          26            bread - per 1kg                 4

# %%
d_product_group = pd.read_excel('../Data/dims.xlsx', sheet_name='d_product_group')
d_product_group.head(2)
# Out:
#    product_group_id  product_group
# 0                 1      preserves
# 1                 2  meat products

# %% [raw]
# 2. nacitat data z cleaned csv subor do df

# %%
df = pd.read_csv('../Data/product_prices_cleaned.csv', sep = ';')
df.head(2)
# Out:
#        province product_types currency  product_group_id  \
# 0  SUBCARPATHIA           NaN      PLN                 2
# 1          ŁÓDŹ           NaN      PLN                 4
#
#                 product_line  value    date                    product
# 0  pork ham cooked - per 1kg  21.37  2013-3  pork ham cooked - per 1kg
# 1            bread - per 1kg    NaN  2018-2            bread - per 1kg

# %% [raw]
# 3. pripojit id pre provinciu z d_province

# %%
df = pd.merge(
    left = df,
    right = d_province,
    how = 'left',
    on = 'province'    
)

# %%
df.head(2)
# Out:
#        province product_types currency  product_group_id  \
# 0  SUBCARPATHIA           NaN      PLN                 2
# 1          ŁÓDŹ           NaN      PLN                 4
#
#                 product_line  value    date                    product  \
# 0  pork ham cooked - per 1kg  21.37  2013-3  pork ham cooked - per 1kg
# 1            bread - per 1kg    NaN  2018-2            bread - per 1kg
#
#    province_id
# 0          8.0
# 1         14.0

# %%
sum(df['province_id'].isna())
# Out:
# 7559

# %%
df[df['province_id'].isna()].head()
# Out:
#    province                            product_types currency  \
# 7    POLAND                                      NaN      PLN
# 13   POLAND         fresh chichen egges - per 10pcs.      PLN
# 15   POLAND  whole pickled cucumbers 0.9l - per 1pc.      PLN
# 16   POLAND                                      NaN      PLN
# 52   POLAND                                      NaN      PLN
#
#     product_group_id                      product_line  value     date  \
# 7                  2       pork belly cooked - per 1kg  19.62   2017-3
# 13                 3                               NaN   0.27   2009-8
# 15                 1                               NaN   2.36  2004-12
# 16                 4                   bread - per 1kg    NaN   2017-9
# 52                 4  Masurian barley groats - per 1kg   2.08   2017-1
#
#                                     product  province_id
# 7               pork belly cooked - per 1kg          NaN
# 13         fresh chichen egges - per 10pcs.          NaN
# 15  whole pickled cucumbers 0.9l - per 1pc.          NaN
# 16                          bread - per 1kg          NaN
# 52         Masurian barley groats - per 1kg          NaN

# %% [raw]
# 4. pripojit id_produktu

# %%
df.columns
# Out:
# Index(['province', 'product_types', 'currency', 'product_group_id',
#        'product_line', 'value', 'date', 'product', 'province_id'],
#       dtype='object')

# %%
d_product.columns
# Out:
# Index(['product_id', 'product', 'product_group_id'], dtype='object')

# %%
df = pd.merge(
    left = df,
    right = d_product,
    how = 'left',
    on = ['product', 'product_group_id'])
df.head(2)
# Out:
#        province product_types currency  product_group_id  \
# 0  SUBCARPATHIA           NaN      PLN                 2
# 1          ŁÓDŹ           NaN      PLN                 4
#
#                 product_line  value    date                    product  \
# 0  pork ham cooked - per 1kg  21.37  2013-3  pork ham cooked - per 1kg
# 1            bread - per 1kg    NaN  2018-2            bread - per 1kg
#
#    province_id  product_id
# 0          8.0        20.0
# 1         14.0        26.0

# %%
sum(df['product_id'].isna())
# Out:
# 4284

# %% [raw]
# 5. Z tabulky extrahujte pouze sloupce, které odkazují na jiné tabulky (např. product_id) a sloupce value, date.

# %%
df.columns
# Out:
# Index(['province', 'product_types', 'currency', 'product_group_id',
#        'product_line', 'value', 'date', 'product', 'province_id',
#        'product_id'],
#       dtype='object')

# %%
df = df[['product_id',  'product_group_id', 'province_id', 'value', 'date']]

# %%
df.shape
# Out:
# (128503, 5)

# %%
df.head(2)
# Out:
#    product_id  product_group_id  province_id  value    date
# 0        20.0                 2          8.0  21.37  2013-3
# 1        26.0                 4         14.0    NaN  2018-2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128503 entries, 0 to 128502
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   product_id        124219 non-null  float64
#  1   product_group_id  128503 non-null  int64
#  2   province_id       120944 non-null  float64
#  3   value             119935 non-null  float64
#  4   date              128503 non-null  object
# dtypes: float64(3), int64(1), object(1)
# memory usage: 4.9+ MB

# %% [markdown]
# ### Cvičení 2: Merge s podmínkami
#
# Pomocí surových dat ze souboru **product_prices_cleaned.csv** zjistěte, kolikrát byla historicky uvedena nižší cena pro daný **produkt, kraj a měsíc**. Postupujte takto:
#
# 1. Spojte tabulku samu se sebou. Jaký typ spojení byste měli použít?
#
# 2. Filtrujte data tak, abyste našli dřívější roky a hodnoty menší než v aktuálním roce v daném kraji.
#
# 3. Seskupte data odpovídajícím způsobem.
#
# Který produkt(y) měl(y) nejvíce takových výskytů?
#
# > Všimněte si, co se stane s názvy sloupců, když sloupce nejsou použity jako podmínka spojení, ale mají stejné názvy.

# %%
# Váš kód zde
df = pd.read_csv('../Data/product_prices_cleaned.csv', sep = ';')

# %%
df = df.head(1000)

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.columns
# Out:
# Index(['province', 'product_types', 'currency', 'product_group_id',
#        'product_line', 'value', 'date', 'product'],
#       dtype='object')

# %%
dfm = pd.merge(
    left = df,
    right = df,
    how = 'inner',
    on = ['product', 'province']    
)
dfm.shape
# Out:
# (2988, 14)

# %%
dfm.columns
# Out:
# Index(['province', 'product_types_x', 'currency_x', 'product_group_id_x',
#        'product_line_x', 'value_x', 'date_x', 'product', 'product_types_y',
#        'currency_y', 'product_group_id_y', 'product_line_y', 'value_y',
#        'date_y'],
#       dtype='object')

# %% [raw]
# maska
# (dfm['date_x'] < dfm ['date_y']) & (dfm['value_x'] <= dfm['value_y'])

# %%
df_fil = dfm.loc[(dfm['date_x'] < dfm ['date_y']) & (dfm['value_x'] <= dfm['value_y'])]
df_fil.shape
# Out:
# (727, 14)

# %%
df_fil.head(2)
# Out:
#           province                   product_types_x currency_x  \
# 10  WARMIA-MASURIA                               NaN        PLN
# 15  WEST POMERANIA  fresh chichen egges - per 10pcs.        PLN
#
#     product_group_id_x                 product_line_x  value_x   date_x  \
# 10                   2  Italian head cheese - per 1kg     5.63   2002-3
# 15                   3                            NaN     0.00  2004-12
#
#                              product                   product_types_y  \
# 10     Italian head cheese - per 1kg                               NaN
# 15  fresh chichen egges - per 10pcs.  fresh chichen egges - per 10pcs.
#
#    currency_y  product_group_id_y                 product_line_y  value_y  \
# 10        PLN                   2  Italian head cheese - per 1kg     8.89
# 15        PLN                   3                            NaN     0.00
#
#     date_y
# 10  2016-1
# 15  2011-6

# %%
df_fil = df_fil.sort_values('product')

# %%
df_fil.head(5)
# Out:
#            province                   product_types_x currency_x  \
# 1711     HOLY CROSS  30% tomato concentrate - per 1kg        PLN
# 1712     HOLY CROSS  30% tomato concentrate - per 1kg        PLN
# 1116     HOLY CROSS  30% tomato concentrate - per 1kg        PLN
# 1117     HOLY CROSS  30% tomato concentrate - per 1kg        PLN
# 2413  LOWER SILESIA  30% tomato concentrate - per 1kg        PLN
#
#       product_group_id_x product_line_x  value_x  date_x  \
# 1711                   1            NaN      0.0  2010-7
# 1712                   1            NaN      0.0  2010-7
# 1116                   1            NaN      0.0  2009-4
# 1117                   1            NaN      0.0  2009-4
# 2413                   1            NaN      0.0  2006-7
#
#                                product                   product_types_y  \
# 1711  30% tomato concentrate - per 1kg  30% tomato concentrate - per 1kg
# 1712  30% tomato concentrate - per 1kg  30% tomato concentrate - per 1kg
# 1116  30% tomato concentrate - per 1kg  30% tomato concentrate - per 1kg
# 1117  30% tomato concentrate - per 1kg  30% tomato concentrate - per 1kg
# 2413  30% tomato concentrate - per 1kg  30% tomato concentrate - per 1kg
#
#      currency_y  product_group_id_y product_line_y  value_y   date_y
# 1711        PLN                   1            NaN      0.0   2011-6
# 1712        PLN                   1            NaN      0.0   2012-3
# 1116        PLN                   1            NaN      0.0   2011-6
# 1117        PLN                   1            NaN      0.0   2012-3
# 2413        PLN                   1            NaN      0.0  2010-11

# %%
# (df_fil['value_x'] != 0) & (df_fil['value_y'] != 0)
df_fil = df_fil.loc[(df_fil['value_x'] != 0) & (df_fil['value_y'] != 0)]
df_fil.head(4)
# Out:
#           province                   product_types_x currency_x  \
# 2077       SILESIA  30% tomato concentrate - per 1kg        PLN
# 1663       SILESIA  30% tomato concentrate - per 1kg        PLN
# 25       POMERANIA  30% tomato concentrate - per 1kg        PLN
# 711   SUBCARPATHIA  30% tomato concentrate - per 1kg        PLN
#
#       product_group_id_x product_line_x  value_x   date_x  \
# 2077                   1            NaN     4.76   2010-8
# 1663                   1            NaN     4.96  2010-11
# 25                     1            NaN     7.46  1999-10
# 711                    1            NaN     8.08   2006-4
#
#                                product                   product_types_y  \
# 2077  30% tomato concentrate - per 1kg  30% tomato concentrate - per 1kg
# 1663  30% tomato concentrate - per 1kg  30% tomato concentrate - per 1kg
# 25    30% tomato concentrate - per 1kg  30% tomato concentrate - per 1kg
# 711   30% tomato concentrate - per 1kg  30% tomato concentrate - per 1kg
#
#      currency_y  product_group_id_y product_line_y  value_y   date_y
# 2077        PLN                   1            NaN     6.07   2013-7
# 1663        PLN                   1            NaN     6.07   2013-7
# 25          PLN                   1            NaN    11.91  2018-12
# 711         PLN                   1            NaN     8.12   2007-5

# %%
df_fil.shape
# Out:
# (457, 14)

# %%
df_fil. groupby(by=['province', 'product', 'date_x']).size().sort_values(ascending=False)
# Out:
# province        product                                           date_x
# SILESIA         plain mixed bread (wheat-rye) - per 1kg           2000-11    5
#                                                                   2000-12    5
# WEST POMERANIA  buckwheat groats roasted whole - per 1kg          2005-10    4
# LESSER POLAND   pork  with bone (center-cut pork chop) - per 1kg  2003-10    4
# WARMIA-MASURIA  plain mixed bread (wheat-rye) - per 1kg           2003-10    4
#                                                                             ..
# WEST POMERANIA  pork  with bone (center-cut pork chop) - per 1kg  2002-1     1
#                 pork belly cooked - per 1kg                       2006-9     1
# ŁÓDŹ            pork belly cooked - per 1kg                       1999-12    1
#                 pork meat with bone (shoulder) - per 1kg          2001-8     1
# GREATER POLAND  Hunter's sausage dried - per 1kg                  2005-12    1
# Length: 293, dtype: int64

# %% [markdown]
# ---
# ## Přehled použitých metod a funkcí
#
# | Funkce/Metoda | Popis |
# |---------------|-------|
# | `pd.merge()` | Spojení dvou DataFrame na základě společných sloupců |
# | `how='left'` | Left join - všechny řádky z levé tabulky |
# | `how='right'` | Right join - všechny řádky z pravé tabulky |
# | `how='inner'` | Inner join - pouze společné řádky (výchozí) |
# | `how='outer'` | Outer join - všechny řádky z obou tabulek |
# | `how='cross'` | Cross join - kartézský součin (každý s každým) |
# | `on` | Sloupec pro spojení (stejný název v obou tabulkách) |
# | `left_on` | Sloupec z levé tabulky pro spojení |
# | `right_on` | Sloupec z pravé tabulky pro spojení |
# | `df.loc[]` | Filtrování DataFrame pomocí logické podmínky |
# | `df.sort_values()` | Seřazení DataFrame podle sloupce |
