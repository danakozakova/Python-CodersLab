# %%
seznam = [1, 2, 3, 4, 5]
tup = (1, 2, 3, 4, 5)
mnozina = {1, 2, 3, 4, 5}
slov = {'id' : 123, 'hodnota' : 25}

# %% [markdown]
# # pridat prvok

# %%
seznam.append(2)
seznam
# Out:
# [1, 2, 3, 4, 5, 2]

# %%
seznam.insert(3, 7)
seznam
# Out:
# [1, 2, 3, 7, 4, 5, 2]

# %%
# novy
tup + (7, )
tup
# Out:
# (1, 2, 3, 4, 5)

# %%
novyt = tup + (7, )
novyt
# Out:
# (1, 2, 3, 4, 5, 7)

# %%
mnozina.add(7)
mnozina
# Out:
# {1, 2, 3, 4, 5, 7}

# %%
slov['kraj'] = 'JM'
slov
# Out:
# {'id': 123, 'hodnota': 25, 'kraj': 'JM'}

# %%
slov['id'] = 555
slov
# Out:
# {'id': 555, 'hodnota': 25, 'kraj': 'JM'}

# %%
slov['id'] = '555'
slov
# Out:
# {'id': '555', 'hodnota': 25, 'kraj': 'JM'}

# %% [markdown]
# # odstranit prvok

# %% [markdown]
# ### seznam

# %%
seznam.pop()
# Out:
# 2

# %%
del seznam[3]

# %%
seznam
# Out:
# [1, 2, 3, 4, 5]

# %%
seznam.remove(1)
seznam
# Out:
# [2, 3, 4, 5]

# %% [markdown]
# ### tupple

# %%
tup
# Out:
# (1, 2, 3, 4, 5)

# %%
# immutable
# napr 4 chcem vyhodit, to index = 3 alebo -2
tup[:3]
# Out:
# (1, 2, 3)

# %%
tup[4:]
# Out:
# (5,)

# %%
tup[:3] + tup[4:]
# Out:
# (1, 2, 3, 5)

# %%
tup
# Out:
# (1, 2, 3, 4, 5)

# %%
novy = tup[:3] + tup[4:]
novy
# Out:
# (1, 2, 3, 5)

# %% [markdown]
# ### mnozina

# %%
mnozina.remove(2)

# %%
mnozina
# Out:
# {1, 3, 4, 5, 7}

# %%
mnozina.remove(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 mnozina.remove(2)
#
# KeyError: 2

# %%
mnozina.discard(2)

# %% [markdown]
# ### slovnik

# %%
slov
# Out:
# {'id': '555', 'hodnota': 25, 'kraj': 'JM'}

# %%
del slov['kraj']

# %%
slov
# Out:
# {'id': '555', 'hodnota': 25}

# %% [markdown]
# ## vybrat hodnotu z toho typu
# napríklad 2. v poradí

# %% [markdown]
# ### seznam

# %%
seznam[2]
# Out:
# 4

# %% [markdown]
# ### tupple

# %%
tup[2]
# Out:
# 3

# %% [markdown]
# ### slovnik

# %%
# nedavame index, ale kluc
slov['id']
# Out:
# '555'

# %%
slov['vek']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 slov['vek']
#
# KeyError: 'vek'

# %%
slov.get('vek')

# %%
slov.get('id')
# Out:
# '555'

# %%
slov.get('vek', 'nenasel jsem')
# Out:
# 'nenasel jsem'

# %% [markdown]
# ### mnozina

# %%
# nejde to, len sa vieme pýtať ci je v mnozine
