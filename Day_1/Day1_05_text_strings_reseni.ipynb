# %% [markdown]
# # Textové řetězce (strings)
#
# ## Co je to string?
#
# String je textový řetězec - prostě jakýkoliv text.
#
# String je cokoliv, co je v uvozovkách.

# %% [markdown]
# ### Jednoduché a dvojité uvozovky
#
# Pro vytvoření stringu můžete použít dvojité uvozovky:

# %%
begin = ("The man in black fled across the desert," +
         " and the gunslinger followed.")
begin
# Out:
# 'The man in black fled across the desert, and the gunslinger followed.'

# %% [markdown]
# Nebo jednoduché uvozovky (apostrofy). Pro Python je to jedno:

# %%
title = 'Harry Potter and the Prisoner of Azkaban'
title
# Out:
# 'Harry Potter and the Prisoner of Azkaban'

# %% [markdown]
# ### Víceřádkové stringy
#
# Pro víceřádkový text použijeme trojité uvozovky:

# %%
screenplay = """
VADER
If only you knew the power of the Dark Side. Obi-Wan never told you what happened
to your father.

LUKE
He told me enough! He told me you killed him!

VADER
No, I am your father.

LUKE - (shocked)
No. No! That's not true! That's impossible!
"""

screenplay
# Out:
# "\nVADER\nIf only you knew the power of the Dark Side. Obi-Wan never told you what happened\nto your father.\n\nLUKE\nHe told me enough! He told me you killed him!\n\nVADER\nNo, I am your father.\n\nLUKE - (shocked)\nNo. No! That's not true! That's impossible!\n"

# %%
print(screenplay)
# Out:
# VADER
# If only you knew the power of the Dark Side. Obi-Wan never told you what happened
# to your father.
#
# LUKE
# He told me enough! He told me you killed him!
#
# VADER
# No, I am your father.
#
# LUKE - (shocked)
# No. No! That's not true! That's impossible!

# %% [markdown]
# ## Zajímavé vlastnosti stringů
#
# ### String jako seznam znaků
#
# Python pracuje se stringem jako se seznamem jednotlivých znaků.
#
# Můžeme ho tedy procházet stejně jako seznam:

# %%
book = ("Harry Potter" +
        " and the Prisoner of Azkaban")

# %%
book
# Out:
# 'Harry Potter and the Prisoner of Azkaban'

# %%
# Prvních 5 znaku: 
# Doplň
book[:5]
# Out:
# 'Harry'

# %%
# Posledních 7 znaků:
# Doplň
book[-7:]
# Out:
# 'Azkaban'

# %% [markdown]
# ### Obrácený string:

# %%
# Doplň
# [start:end:step]
book[::-1]
# Out:
# 'nabakzA fo renosirP eht dna rettoP yrraH'

# %% [markdown]
# ### Iterace přes string
#
# Přes string můžeme po písmenech iterovat pomocí cyklu:

# %%
# Vypis vsechny písmena okrem mezery
# Doplň
for znak in book:
    print(znak, end = "")
# Out:
# Harry Potter and the Prisoner of Azkaban

# %%
for znak in book:
    if znak != " ":
        print(znak, end = "")
# Out:
# HarryPotterandthePrisonerofAzkaban

# %%
# Vypis jenom pismena z prvniho slova / nebo prvních 10 znaku
for index in range(10):
    print(book[index], end = "")
# Out:
# Harry Pott

# %%
for znak in book[:10]:
    print(znak, end = "")
# Out:
# Harry Pott

# %% [markdown]
# ### Úloha 1: Doplň chybějící kód
#
# Doplň kód tak, aby vypsal prvních 10 znaků a poslední slovo ze stringu `veta`:

# %%
veta = "Python je skvělý programovací jazyk"

# %%
# Prvních 10 znaků:

# %%
# Poslední slovo ("jazyk"):

# %% [markdown]
# ### Úloha 2: Doplň
#
# Následující kód není dokončen:

# %%
text = "Programování"

# Chceme vypsat každý druhý znak:
for i in range(0, len(text)):
    print(text[i])

# %% [markdown]
# ## Formátování stringů
#
# ### Spojování stringů operátorem +
#
# Stringy lze spojovat operátorem `+`:

# %%
print("Bilbo" + "Baggins")

# %% [markdown]
# Pozor - mezi slova se mezera nedoplní automaticky!

# %% [markdown]
# ### Úloha 3: Oprav výstup
#
# Uprav kód tak, aby mezi jménem a příjmením byla mezera:

# %%
jmeno = "Bilbo"
prijmeni = "Baggins"

# %%
# Uprav:
cele_jmeno = jmeno + prijmeni
print(cele_jmeno)

# %% [markdown]
# ### Formátování pomocí %
#
# Starší způsob formátování - podobný jako v jazyce C:

# %%
hobbits = ("Frodo", "Sam", "Merry", "Pippin")

desc = ("Hobbits in LOTR: %s, %s, %s" +
        " and %s.") % hobbits

print(desc)

# %% [markdown]
# Důležité pravidlo:
# Počet %s musí odpovídat počtu prvků v tuple!
# * 4× %s = potřebujeme 4 prvky
# * Pokud by bylo méně/více, dostanete chybu

# %% [markdown]
# ### Metoda format()
#
# Modernější způsob formátování:

# %%
description = "{} is a {}.".format("Gandalf The Grey", "wizard")

print(description)

# %% [markdown]
# S pojmenovanými parametry:

# %%
description = "{name} je {occupation}.".format(
    name="Fero",
    occupation="obchodník"
)

print(description)

# %% [markdown]
# ### F-stringy (od Pythonu 3.6)
#
# Nejmodernější a nejčitelnější způsob formátování:

# %%
name = "Han Solo"
occupation = "smuggler"

description = f"{name} is a {occupation}."

print(description)

# %% [markdown]
# ### Úloha 4: Vytvoř f-string
#
# Použij f-string k vytvoření věty o svém oblíbeném filmu nebo knize:

# %%
# Tvůj kód zde:
nazev = ""  # Doplň název
zanr = ""   # Doplň žánr

# Vytvoř f-string:

# %% [markdown]
# ### Úloha 5: Oprav chyby
#
# Následující kódy obsahují chyby. Oprav je:

# %%
# Chyba 1:
text = 'It's a beautiful day'
print(text)

# %%
jmeno = "Karel"
vek = 25

# %%
# Chyba 2:
vysledek = f"{jmeno} je {věk} let starý."

print(vysledek)

# %% [markdown]
# ### Úloha 6: Vytvoř jednoduchý program
#
# Napiš program, který:
# 1. Vytvoří několik proměnných s informacemi o osobě (jméno, věk, město, povolání)
# 2. Vypíše tyto informace ve formátované větě pomocí f-stringu
# 3. Vypíše jméno pozpátku
# 4. Vypíše každé třetí písmeno ze jména

# %% [markdown]
# Řešení

# %%
# Tvůj kód zde:
# 1. Vytvoření proměnných s informacemi o osobě
jmeno = "Dana Kozáková"
vek = 35
mesto = "Brno"
povolani = "IT analytik"

# %%
# 2. Výpis informací pomocí f-stringu
print(f"Jmenuji se {jmeno}, moje mesto je {mesto} a pracuji jako {povolani}")
# Out:
# Jmenuji se Dana, moje mesto je Brno a pracuji jako IT analytik

# %%
# 3. Jméno pozpátku
jmeno[::-1]
# Out:
# 'ávokázoK anaD'

# %%
# 4. Každé třetí písmeno ze jména

# %%
jmeno[::3]
# Out:
# 'Daoká'

# %% [markdown]
# ### Úloha 7: Vytvoř email

# %% [raw]
# Vytvor funkci pro email dle vzoru:
# - zadáš jméno a příjmení, např. Dana Kozakova
# - funkce vráti email ve tvaru: d.kozakova@coder.com (prvni iniciala, prijmeni, vsechno male)
#
# pre retezce: lower()

# %%
jmeno = 'Dana'
prijmeni = 'Kozakova'

# %%
jmeno[0]
# Out:
# 'D'

# %%
jmeno.lower()
# Out:
# 'dana'

# %%
jmeno.lower()[0]
# Out:
# 'd'

# %%
prijmeni.lower()
# Out:
# 'kozakova'

# %%
def vrat_email(jmeno, prijmeni):
    email = jmeno.lower()[0] + '.' + prijmeni.lower()
    return email

# %%
# otestujem
vrat_email('Dana', 'Kozakova')
# Out:
# 'd.kozakova'

# %%
def vrat_email(jmeno, prijmeni):
    email = jmeno.lower()[0] + '.' + prijmeni.lower() + '@coders.com'
    return email

# %%
# otestujem
vrat_email('Dana', 'Kozakova')
# Out:
# 'd.kozakova@coders.com'

# %%
def vrat_email(jmeno, prijmeni):
    return jmeno.lower()[0] + '.' + prijmeni.lower() + '@coders.com'

# %%
# otestujem
vrat_email('Dana', 'Kozakova')
# Out:
# 'd.kozakova@coders.com'
