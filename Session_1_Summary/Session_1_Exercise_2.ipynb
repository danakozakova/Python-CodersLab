# %% [markdown]
# # Cvičení 2 - Hledání prvního opakujícího se písmene
#
# ## Zadání
#
# Napište funkci `find_first_duplicate(text)`, která přijímá řetězec jako argument a vrací první písmeno, které se od své pozice až do konce řetězce vyskytuje více než jednou. Pokud se žádné písmeno neopakuje, funkce by měla vrátit `None`.
#
# ### Příklad:
#
# ```python
# print(find_first_duplicate('Calamary'))
# ```
#
# ### Výsledek:
# ```
# a
# ```
#
# **Vysvětlení:** Písmeno 'a' se poprvé objeví na pozici 1 a potom se ještě dvakrát opakuje dále v řetězci.

# %% [markdown]
# ---
#
# ## Krok za krokem řešení
#
# ### Krok 1: Vytvoření prázdné funkce
#
# Začneme vytvořením základní struktury funkce:

# %%
# Test, že funkce existuje
find_first_duplicate('test')  # zatím nic nevrací

# %% [markdown]
# ### Krok 2: Procházení písmen v řetězci
#
# Podle zadání potřebujeme zkontrolovat každé písmeno postupně. K tomu použijeme cyklus `for`:

# %%
# Zkouška - co se stane při volání funkce?
find_first_duplicate('monitor')

# %% [markdown]
# **Co se děje:**
# - Když zavoláme funkci s hodnotou `"monitor"`, cyklus `for` postupně projde písmena: `"m"`, pak `"o"`, pak `"n"`, atd.
# - Zatím jen vypisujeme každé písmeno, ale ještě nerozhodujeme, zda se opakuje

# %% [markdown]
# ### Krok 3: Zjištění, kolikrát se písmeno vyskytuje
#
# Potřebujeme zjistit, jestli se aktuální písmeno vyskytuje v řetězci více než jednou. K tomu použijeme metodu `.count()`:

# %%
# Zkouška
find_first_duplicate('monitor')

# %% [markdown]
# **Poznámka:** Metoda `.count()` spočítá, kolikrát se daný znak vyskytuje v celém řetězci.

# %% [markdown]
# ### Krok 4: Vrácení prvního opakujícího se písmene
#
# Pokud se písmeno vyskytuje více než jednou (`count > 1`), vrátíme ho pomocí `return`:

# %%
# Zkouška
print(find_first_duplicate('monitor'))  # mělo by vrátit 'o'
print(find_first_duplicate('processor'))  # mělo by vrátit 'r'
print(find_first_duplicate('mouse'))  # mělo by vrátit None

# %% [markdown]
# **Co se děje:**
# - Cyklus prochází písmena postupně zleva doprava
# - Když najde první písmeno, které se vyskytuje více než jednou, okamžitě ho vrátí pomocí `return`
# - Příkaz `return` ukončí funkci, takže se další písmena již nekontrolují
# - Pokud se žádné písmeno neopakuje, funkce doběhne do konce a automaticky vrátí `None`

# %% [markdown]
# ---
#
# ## Finální řešení

# %%
def find_first_duplicate(text):

    
    # Pokud se funkce dostane sem, žádné písmeno se neopakuje
    # V takovém případě Python automaticky vrátí None

# %% [markdown]
# ---
#
# ## Testování

# %%
# Test 1
if find_first_duplicate('processor') == 'r':
    print('Test 1 prošel!')
else:
    print("Pro argument 'processor' očekáváme návratovou hodnotu 'r'")
    print('Vaše funkce vrátila:', find_first_duplicate('processor'))

# Test 2
if find_first_duplicate('monitor') == 'o':
    print('Test 2 prošel!')
else:
    print("Pro argument 'monitor' očekáváme návratovou hodnotu 'o'")
    print('Vaše funkce vrátila:', find_first_duplicate('monitor'))

# Test 3
if find_first_duplicate('mouse') == None:
    print('Test 3 prošel!')
else:
    print("Pro argument 'mouse' očekáváme návratovou hodnotu None")
    print('Vaše funkce vrátila:', find_first_duplicate('mouse'))

# %% [markdown]
# ---
#
# ## Další příklady na vyzkoušení

# %%
# Zkuste si další příklady:
print(find_first_duplicate('Calamary'))  # 'a'
print(find_first_duplicate('hello'))  # 'l'
print(find_first_duplicate('python'))  # None
print(find_first_duplicate('Programming'))  # 'r'

# %% [markdown]
# ---
#
# ## Zamyšlení
#
# 1. Proč funkce automaticky vrací `None`, pokud nenajde žádné opakující se písmeno?
# 2. Co se stane, když předáme funkci prázdný řetězec `""`?
# 3. Rozlišuje naše funkce velká a malá písmena? Měla by?
