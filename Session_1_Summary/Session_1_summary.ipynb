# %% [markdown]
# # CSV soubory
#
# CSV (Comma Separated Values) jsou textové soubory, které se používají k ukládání tabulkových dat.
#
# **Příklad CSV souboru:**
# ```
# John,Doe,120 jefferson st.,Riverside, NJ, 08075
# Jack,McGinnis,220 hobo Av.,Phila, PA,09119
# ```
#
# - Jeden řádek = jeden záznam
# - Hodnoty oddělené čárkami
# - Python má modul `csv` pro práci s těmito soubory

# %% [markdown]
# ## Import modulu csv
#
# 🔧 ÚLOHA / DOPLNĚNÍ
#
# Doplň chybějící kód pro import modulu csv:

# %%
# Importuj modul csv

# %% [markdown]
# ## Čtení CSV souboru
#
# Pro čtení CSV souboru použijeme funkci `csv.reader()`.
#
# **Důležité:** Při otevírání CSV souboru musíme použít parametr `newline=''`

# %% [markdown]
# ### Vytvoření ukázkového CSV souboru
#
# Nejprve si vytvoříme testovací soubor `addresses.csv`:

# %%
# Vytvoříme ukázkový CSV soubor
import csv

with open('addresses.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['John', 'Doe', '120 jefferson st.', 'Riverside', ' NJ', ' 08075'])
    writer.writerow(['Jack', 'McGinnis', '220 hobo Av.', 'Phila', ' PA', '09119'])
    writer.writerow(['John "Da Man"', 'Repici', '120 Jefferson St.', 'Riverside', ' NJ', '08075'])
    writer.writerow(['Stephen', 'Tyler', '7452 Terrace "At the Plaza" road', 'SomeTown', 'SD', ' 91234'])
    writer.writerow(['', 'Blankman', '', 'SomeTown', ' SD', ' 00298'])
    writer.writerow(['Joan "the bone", Anne', 'Jet', '9th, at Terrace plc', 'Desert City', 'CO', '00123'])

print('Soubor addresses.csv byl vytvořen')

# %% [markdown]
# ### Čtení řádků ze souboru
#
# 🔧 ÚLOHA / DOPLNĚNÍ
#
# Doplň chybějící části kódu pro čtení CSV souboru:

# %%
import csv

with open('addresses.csv', newline='') as my_file:
    addresses = csv._____(my_file)  # Doplň správnou funkci
    for line in _____:  # Doplň název proměnné
        print('Řádek ze souboru:', line)

# %% [markdown]
# **Otázka k zamyšlení:**
# - Jaký datový typ má proměnná `line`?
# - Jak bys přistoupil k prvnímu prvku (jménu) v řádku?

# %% [markdown]
# ### Přístup k jednotlivým hodnotám
#
# 🔧 ÚLOHA / DOPLNĚNÍ
#
# Přečti soubor a vypiš pouze jména a příjmení (první dva sloupce):

# %%
import csv

with open('addresses.csv', newline='') as my_file:
    addresses = csv.reader(my_file)
    for line in addresses:
        jmeno = line[___]  # Doplň správný index
        prijmeni = line[___]  # Doplň správný index
        print(f'Jméno: {jmeno}, Příjmení: {prijmeni}')

# %% [markdown]
# ## Zápis do CSV souboru
#
# Pro zápis použijeme funkci `csv.writer()` a metodu `writerow()`.

# %% [markdown]
# ### Základní zápis
#
# 🔧 ÚLOHA / DOPLNĚNÍ
#
# Doplň chybějící části kódu pro vytvoření souboru `users.csv`:

# %%
import csv

with open('users.csv', '___', newline='') as my_file:  # Doplň režim otevření souboru
    writer = csv._____(my_file)  # Doplň správnou funkci
    writer.writerow(['John', 'Connor', 'jconnor@mywebsite.org'])
    writer.writerow(['Anna', 'Newman', 'anewman@mywebsite.org'])

print('Soubor users.csv byl vytvořen')

# %% [markdown]
# ### Kontrola výsledku
#
# Přečteme vytvořený soubor, abychom zkontrolovali, že vše funguje správně:

# %%
import csv

with open('users.csv', newline='') as my_file:
    reader = csv.reader(my_file)
    for line in reader:
        print(line)

# %% [markdown]
# ## Oprava chyb
#
# 🔧 ÚLOHA / OPRAVA CHYB
#
# Následující kód obsahuje chyby. Najdi a oprav je:

# %%
import csv

# Tento kód má chyby - oprav je!
with open('test.csv', 'w') as my_file:
    writer = csv.reader(my_file)
    writer.writerow('Jan', 'Novák', 'jan@email.cz')

# %% [markdown]
# **Otázky k chybám:**
# 1. Co chybí v parametrech funkce `open()`?
# 2. Je použita správná funkce z modulu `csv`?
# 3. Je metoda `writerow()` použita správně?

# %% [markdown]
# ## Praktické úlohy

# %% [markdown]
# ### Úloha 1: Seznam studentů
#
# Vytvoř CSV soubor `studenti.csv` s následujícími údaji:
# - Hlavička: Jméno, Příjmení, Třída, Průměr
# - Alespoň 3 studenty s různými údaji

# %%
# Tvůj kód zde

# %% [markdown]
# ### Úloha 2: Čtení a filtrace
#
# Přečti soubor `addresses.csv` a vypiš pouze ty řádky, kde je stát (5. sloupec) roven ` NJ`:

# %%
# Tvůj kód zde

# %% [markdown]
# ### Úloha 3: Kopírování dat
#
# Přečti soubor `users.csv` a zkopíruj všechny záznamy do nového souboru `users_backup.csv`:

# %%
# Tvůj kód zde

# %% [markdown]
# ### Úloha 4: Přidání nového záznamu
#
# Přečti soubor `users.csv`, přidej nový záznam (např. `['Peter', 'Parker', 'pparker@mywebsite.org']`) a ulož vše do stejného souboru:

# %%
# Tvůj kód zde

# %% [markdown]
# ### Úloha 5: Počítání řádků
#
# Přečti soubor `addresses.csv` a vypiš celkový počet řádků (záznamů) v souboru:

# %%
# Tvůj kód zde
